# %% [markdown]
# # Analisis datos encontrados por medio de grupos

# %% [markdown]
# ## Carga de librerias
# Empezamos cargando librerias.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ## Carga y formateo
# - Cargo los datos
# - Creo grupos interesantes apartando la hora y los minutos para pasar al algoritmo si crea que no inutilies o causan problemas elimino y pruebo otros

# %%
df = pd.read_csv('completo_clusters.csv')

# %% [markdown]
# Okey no interpreto nada con los datos en crudo, vamos a añadir graficos

# %% [markdown]
# ## Representacion mediante graficos
# Esto ayuda a entender en su totalidad los datos
#
# 1. Muestro los centroides

# %%
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
sns.set_style("whitegrid")
CLUSTER_LABELS = {0: 'SATURADO', 1: 'FLUIDO', 2: 'VACIO'}
COLOR_MAP = {'SATURADO': '#d62728', 'FLUIDO': '#2ca02c', 'VACIO': '#1f77b4'}
df['Estado'] = df['cluster'].map(CLUSTER_LABELS)
colors = df['Estado'].map(COLOR_MAP)

scatter = ax.scatter(
    df['Ocupacion_Espacial_%'],
    df['Tiempo_Medio_s'],
    df['Total_Vehiculos'],
    c=colors,
    s=40,
    alpha=0.6,
    edgecolors='k',
    linewidth=0.5
)

ax.set_xlabel('Ocupación (%)', fontsize=12, labelpad=10)
ax.set_ylabel('Tiempo (s)', fontsize=12, labelpad=10)
ax.set_zlabel('Total Vehículos', fontsize=12, labelpad=10)
ax.set_title('Separación Tridimensional de los Clusters', fontsize=16, fontweight='bold')

ax.view_init(elev=20, azim=45)

plt.tight_layout()
plt.show()
