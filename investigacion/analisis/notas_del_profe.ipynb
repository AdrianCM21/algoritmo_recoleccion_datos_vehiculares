# %% [markdown]
# **Nota 1:**
#
# Por ahí antes de realiza todos esto análisis es prudente mostrar la distribuirnos por día en base a dataset que están usando, con el fin de saber la estructura, y las cantidades que están dentro de esta estructura, primero saber saber si todos los días tienen las misma cantidad de registros por día (estructura) y luego dentro de esa estructura saber como están dispersos esos datos.
#
# ![WhatsApp Image 2026-01-08 at 10.26.33.jpeg](<attachment:WhatsApp Image 2026-01-08 at 10.26.33.jpeg>)
#
# por ejemplo no es lo mismo que el día 1 tenga 400 registros que el día 2 tenga 500
# esto hay que ver porque esta alejado (azul) y este porque se entan solapando (rojo)
#  sus exploraciones estan bien siempre y cuando tenga un porque.. y lo entiendan...
#
# ---
#
# **Nota 2:**
