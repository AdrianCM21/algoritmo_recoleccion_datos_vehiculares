# %% [markdown]
# Carga de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

plt.style.use('ggplot')
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns
#       5 from sklearn.preprocessing import StandardScaler, LabelEncoder
#       6 from sklearn.cluster import KMeans
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# a continuacion cargamos y limpiamos los datos

# %%
df = pd.read_csv('resultados_ocupacion_espacial.csv')


print("\nInformación del tipo de datos:")
df.info()

df['Hora_Inicio'] = pd.to_datetime(df['Hora_Inicio'], format='%H:%M:%S')
df['Hora_Entera'] = df['Hora_Inicio'].dt.hour


# Seleccionamos las columnas útiles para el Clustering
# NO usamos 'Hora_Inicio' (texto) ni 'Dia_Semana' (texto).
# Usamos las versiones numéricas.
features = ['Total_Vehiculos', 'Tiempo_Medio_s', 'Ocupacion_%', 'Hora_Entera', 'Dia_Codificado']

X = df[features]
print("\nDatos listos para escalar:")
display(X.head())
