# %% [markdown]
# # Datos por dirección
#
# 1. **Dirección 1**: Japón → camino al circuito
# 2. **Dirección 2**: Japón → camino al centro
# 3. **Dirección 3**: Japón → camino a la rotonda
# 4. **Dirección 4**: Japón → camino a la playa
#
# ## Análisis del dataset completo
#
# ### Distribucion del dataset
#
# Se procede a mostrar
#
# 1. Total de los datos registrados ya etiquetados.
# 2. Total de registros por dia de la semana.
# 3. Total de registros por direccion.
#
# ![image.png](attachment:image.png)
#
# La distribución completa del dataset, al aplicar la técnica de clustering, permite identificar patrones claros en el tráfico vehicular. Se formaron 3 clusters principales con características distintas.

# %% [markdown]
# <style type="text/css">
# #T_dd542_row0_col0, #T_dd542_row0_col2, #T_dd542_row1_col3, #T_dd542_row2_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_dd542_row0_col1, #T_dd542_row2_col0, #T_dd542_row2_col2, #T_dd542_row2_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_dd542_row0_col3 {
#   background-color: #34b679;
#   color: #f1f1f1;
# }
# #T_dd542_row1_col0 {
#   background-color: #424086;
#   color: #f1f1f1;
# }
# #T_dd542_row1_col1 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_dd542_row1_col2 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dd542">
#   <caption>Centroides de Clusters</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd542_level0_col0" class="col_heading level0 col0" >Total_Vehiculos</th>
#       <th id="T_dd542_level0_col1" class="col_heading level0 col1" >Tiempo_Medio_s</th>
#       <th id="T_dd542_level0_col2" class="col_heading level0 col2" >Ocupacion_Espacial_%</th>
#       <th id="T_dd542_level0_col3" class="col_heading level0 col3" >Cantidad_muestras</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd542_level0_row0" class="row_heading level0 row0" >Cluster 0</th>
#       <td id="T_dd542_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_dd542_row0_col1" class="data row0 col1" >-0.28</td>
#       <td id="T_dd542_row0_col2" class="data row0 col2" >0.97</td>
#       <td id="T_dd542_row0_col3" class="data row0 col3" >1470.00</td>
#     </tr>
#     <tr>
#       <th id="T_dd542_level0_row1" class="row_heading level0 row1" >Cluster 1</th>
#       <td id="T_dd542_row1_col0" class="data row1 col0" >-0.57</td>
#       <td id="T_dd542_row1_col1" class="data row1 col1" >-0.12</td>
#       <td id="T_dd542_row1_col2" class="data row1 col2" >-0.58</td>
#       <td id="T_dd542_row1_col3" class="data row1 col3" >2113.00</td>
#     </tr>
#     <tr>
#       <th id="T_dd542_level0_row2" class="row_heading level0 row2" >Cluster 2</th>
#       <td id="T_dd542_row2_col0" class="data row2 col0" >-0.93</td>
#       <td id="T_dd542_row2_col1" class="data row2 col1" >3.06</td>
#       <td id="T_dd542_row2_col2" class="data row2 col2" >-0.91</td>
#       <td id="T_dd542_row2_col3" class="data row2 col3" >218.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Análisis de los 3 grupos
#
# **Cluster 0:**
# - **Vehiculos:** 0.95 - alto
# - **Tiempo medio entre autos:** - 0.28 - bajo
# - **Ocupacion:** 0.97 - alto
# - **Cantidad:** 1.470
#
# Se puede observar que en este cluster el flujo vehicular es muy alto, los vehículos circulan muy cercanos entre sí debido al reducido tiempo medio entre vehículos, y la ocupación del carril es casi completa. Este cluster corresponde a tráfico pesado, donde se ocupa gran parte del carril y los vehículos avanzan de forma densa.
#
# **Cluster 1:**
# - **Vehiculos:** -0.57 - moderado/bajo
# - **Tiempo medio entre autos:** -0.12 - moderado/bajo
# - **Ocupacion:** -0.58 - moderado/bajo
# - **Cantidad:** 2.113
#
# En este cluster se observa un tráfico moderado, con menos vehículos que el Cluster 0. El tiempo medio entre vehículos es ligeramente bajo, lo que indica un flujo continuo pero sin saturación. La ocupación del carril es parcial, lo que permite cierto espacio entre vehículos y una circulación más fluida.
#
# **Cluster 2:**
# - **Vehiculos:** -0.93 - bajo
# - **Tiempo medio entre autos:** 3.06 - alto
# - **Ocupacion:** -0.91 - bajo
# - **Cantidad:** 218
#
# Este cluster representa tráfico ligero. La cantidad de vehículos es baja, el tiempo medio entre ellos es alto, y la ocupación del carril es mínima. Se corresponde a periodos de baja densidad de tráfico, donde los vehículos circulan con amplio espacio.
#
# Distrubucion grafica de los datos
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ## Distribución del total del dataset por calle
#
# Se realizara el analisis del total de cada calle, considerando los centroides obtenidos para cada cluster: **Fluido**, **Saturado** y **Vacio**.
#
# ![image.png](attachment:image.png)
#
# ---
#
# ### Análisis por dirección
#
# #### Dirección 1
# - **Estado Saturado:**
#   Se observan valores alto en el total y la ocupacion, junto con tiempo entre vehiculos bajos.
#   Esto indica un alto flujo vehicular con vehículos muy próximos, esto indica tráfico denso.
#
# - **Estado Fluido:**
#   Muestra valores negativos moderados en las tres variables, indica una circulación estable sin congestión.
#
# - **Estado Vacío:**
#   Observamos un tiempo medio entre vehiculos alto (2.49) y valores negativos en volumen y ocupación, lo que indica periodos de baja circulación.
#
#
# ### Dirección 2
# - **Estado Saturado:**
#   Se observa un comportamiento similar a la Dirección 1, con total y ocupacion elevados, lo que confirma escenarios de tráfico intenso.
#
# - **Estado Fluido:**
#   Mantiene valores bajos y estables, indicando tránsito continuo sin acumulaciones.
#
# - **Estado Vacío:**
#   Presenta un tiempo medio entre vehiculos muy alto (3.07), señal de amplios intervalos entre vehículos y mínima ocupación del carril.
#
#
# ### Dirección 3
# - **Estado Saturado:**
#   Registra valores altos en total y ocupacion, con un tiempo medios entre vehiculos reducido (-0.37), lo que sugiere congestión frecuente.
#
# - **Estado Fluido:**
#   Se mantiene en niveles moderados, permitiendo una circulación más ordenada.
#
# - **Estado Vacío:**
#   Muestra menor presencia vehicular y un tiempo medios entre vehiculos elevado (2.61), correspondiente a tráfico liviano.
#
#
# ### Dirección 4
# - **Estado Saturado:**
#   Presenta valores altos en total y ocupacion, estos son ligeramente menores a otras direcciones, indicando saturación menos extrema.
#
# - **Estado Fluido:**
#   Se observa un tránsito estable con valores cercanos a cero en las variables.
#
# - **Estado Vacío:**
#   Destaca un tiempo medios entre vehiculos muy alto (4.15), el mayor entre todas las direcciones, lo que evidencia largos periodos sin paso de vehículos.
#
# ### Carga de los grupos y totales de los resultados
# #### Carga
#
# ![image-2.png](attachment:image-2.png)
#
# #### Totales
# ![image-3.png](attachment:image-3.png)
#
# ### Conclucion
# | Se confirma que el comportamiento del tráfico es coherente entre calles, con diferencias minimas entre cada una

# %% [markdown]
# ## Distribución del total del dataset por dia
#
# Ahora se realizara el analisis por separado de cada dia, considerando los centroides obtenidos para cada cluster: **Fluido**, **Saturado** y **Vacio**.
#
# ### Analisis por dia
#
# ![image.png](attachment:image.png)
#
# #### Dia 1
# - **Estado Saturado:**
#   Se observan valores alto en el total y la ocupacion, junto con tiempo entre vehiculos bajos.
#   Esto indica un alto flujo vehicular con vehículos muy próximos, esto indica tráfico denso.
#
# - **Estado Fluido:**
#   Muestra valores negativos moderados en las tres variables, indica una circulación estable sin congestión.
#
# - **Estado Vacío:**
#   Observamos un tiempo medio entre vehiculos alto (2.49) y valores negativos en volumen y ocupación, lo que indica periodos de baja circulación.
#
#
# #### Días 2 al 5
# Al observar los mapas de calor para los días subsiguientes (Dia 2 a Dia 5), se evidencia que los patrones definidos en el Día 1 se mantienen altamente consistentes:
#
# Saturacian: En todos los días observados (1-5), la columna "SATURADO" presenta invariablemente valores altos en Total_Vehiculos y Ocupacion_Espacial_%. Esto confirma que el estado de congestión densa tiene la misma firma de datos a lo largo de la semana.
#
# Fluidez: De manera similar, la columna "FLUIDO" mantiene valores negativos moderados en las tres variables medidas a través de los cinco días.
#
# Estado Vacío: El patrón de "VACIO" es notablemente estable, caracterizado en los cinco mapas de calor por un Tiempo_Medio_s muy elevado.
#
# ### Carga de grupos y totales
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ### Conclusión
# El análisis visual de los cinco días presentados denotan una alta estabilidad en los patrones del tráfico. Las definiciones de los estados "Saturado" (alta densidad, intervalos cortos) y "Fluido" (valores moderados bajos, circulación estable), establecidas textualmente para el Día 1.
#
# ---
